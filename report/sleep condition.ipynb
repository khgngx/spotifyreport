# %%
import pandas as pd 
df = pd.read_csv(r'D:\dataset\clean\Health behaviors_ places within United States of America.csv')
df
# Out:
#     Entity DCID Entity properties isoCode    Entity properties name  \
# 0   country/USA                        US  United States of America
# 1   country/USA                        US  United States of America
# 2   country/USA                        US  United States of America
# 3   country/USA                        US  United States of America
# 4   country/USA                        US  United States of America
# 5      geoId/06                     US-CA                California
# 6      geoId/06                     US-CA                California
# 7      geoId/06                     US-CA                California
# 8      geoId/06                     US-CA                California
# 9      geoId/06                     US-CA                California
# 10     geoId/12                     US-FL                   Florida
# 11     geoId/12                     US-FL                   Florida
# 12     geoId/12                     US-FL                   Florida
# ...
