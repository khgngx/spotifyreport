# %% [markdown]
# # Project: Investigate a Dataset - [TMDb Movie Data]
#
# ## Table of Contents
# - [Introduction](#introduction)
# - [Data Wrangling](#datawrangling)
# - [Exploratory Data Analysis](#exploratory-data-analysis)
# - [Conclusions](#conclusions)
# ## Introduction
# ### Data Description

# %%
import pandas as pd
path = r"D:\dataset\tmdb_5000_movies.csv"
df = pd.read_csv(path)
print(f"This project useses tmdb-movies dataset. This dataset has a shape of {df.shape[0]} rows and {df.shape[1]} columns containing information about movies released from ... . Information of a film has the following attributes:")
# Out:
# This project useses tmdb-movies dataset. This dataset has a shape of 4803 rows and 20 columns containing information about movies released from ... . Information of a film has the following attributes:

# %%
df = df.rename(columns={"release_date": "Release Date"})
print("Tên cột:")
print(f"Giá trị lớn nhất của cột '{Release Date}': {max_value}")
print(f"Giá trị nhỏ nhất của cột '{Release Date}': {min_value}")
print(df.columns.tolist())
print("\nKiểu dữ liệu của từng cột:")
print(df.dtypes)
print(df.columns)
# Out:
# Tên cột:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'Release Date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']
#
# Kiểu dữ liệu của từng cột:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# Release Date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# ...
