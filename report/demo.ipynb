# %%
import pandas as pd

# Đọc file Excel, bỏ qua 4 dòng đầu
file_path = r"D:\dataset\messy\LICH THI KTHP_HKII NH 2023-2024_KHOA 23_Gui SV.xlsx"
df = pd.read_excel(file_path, skiprows=4)

# Kiểm tra tên các cột có trong file
print(df.columns)

# 🔧 Gán tên cột chính xác sau khi kiểm tra (ví dụ bên dưới có thể cần chỉnh)
ten_mon_col = "Tên học phần"         # <-- chỉnh lại đúng nếu tên khác
hinh_thuc_thi_col = "Hình thức thi"  # <-- chỉnh lại đúng nếu tên khác

# Môn cần lọc
cac_mon_can_lay = ["Pháp luật đại cương"]

# Lọc dữ liệu
df_filtered = df[[ten_mon_col, hinh_thuc_thi_col]]
df_filtered = df_filtered[df_filtered[ten_mon_col].isin(cac_mon_can_lay)]

# Hiển thị kết quả
print(df.columns.tolist())
# Out:
# Index(['LỊCH THI KẾT THÚC HỌC PHẦN HỌC KÌ II - NĂM HỌC: 2023 - 2024 (CHÍNH THỨC)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 18
#      15 cac_mon_can_lay = ["Pháp luật đại cương"]
#      17 # Lọc dữ liệu
# ---> 18 df_filtered = df[[ten_mon_col, hinh_thuc_thi_col]]
# ...
