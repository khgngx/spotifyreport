# %%
import pandas as pd
import numpy as np
df =pd.read_csv(r'D:\jn\report\file_updated.csv')
df.head(5)
# Out:
#                          Country ISO Code  \
# 0                         Russia       RU
# 1  Canada - Adult (16 and older)       CA
# 2   Canada - Children (under 16)       CA
# 3                      Indonesia       ID
# 4                           Iran       IR
#
#   Passport Photo Size (Width x Height, mm)  \
# 0                                  35 x 45
# 1                                  50 x 70
# 2                                  50 x 70
# 3                                  51 x 51
# 4                                  40 x 60
#
#   Passport Photo Size (Width x Height, inch)  \
# 0                                1.38 x 1.77
# 1                                1.97 x 2.76
# 2                                1.97 x 2.76
# 3                                2.01 x 2.01
# 4                                1.57 x 2.36
#
#   Visa Photo Size (Width x Height, mm) Visa Photo Size (Width x Height, inch)  \
# 0                              35 x 45                            1.38 x 1.77
# ...
