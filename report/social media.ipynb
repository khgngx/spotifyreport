# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel(r'D:\dataset\Social Meida Dataset.xlsx')
df.head(15)
# Out:
#     Consumer ID   Customer Name  Age      Gender  Income (USD)  \
# 0             1   Alice Johnson   28      Female         45000
# 1             2       Bob Smith   35        Male         60000
# 2             3    Chris Taylor   22  Non-binary         32000
# 3             4     David Brown   40        Male         75000
# 4             5     Emily White   29      Female         55000
# 5             6     Frank Davis   45        Male         80000
# 6             7     Grace Smith   32      Female         58000
# 7             8  Hannah Johnson   25      Female         40000
# 8             9  Ivan Hernandez   30        Male         62000
# 9            10      Jane Adams   27      Female         48000
# 10           11     Karen White   38      Female         70000
# 11           12     Liam Martin   24        Male         36000
# 12           13      Mia Garcia   31      Female         56000
# 13           14   Noah Anderson   26        Male         48000
# ...
