# %%
import pandas as pd # type: ignore
import numpy as np
df = pd.read_csv(r'C:\Users\ADMIN\Downloads\passport_photo_requirements (1).csv')
df.iloc[1, 4] = "35 x 45"
df.iloc[2, 4] = "35 x 45"
df.iloc[0,18] = "2025-03-16"

UnitedStates = pd.DataFrame([{
    "Country": "United States",
    "ISO Code": "US",
    "Passport Photo Size (Width x Height, mm)": "51 x 51",
    "Passport Photo Size (Width x Height, inch)": "2 x 2",
    "Visa Photo Size (Width x Height, mm)": "51 x 51",
    "Visa Photo Size (Width x Height, inch)": "2 x 2",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": "1:1",
    "Aspect Ratio (Visa)": "1:1",
    "Background Color": "Plain white or off-white",
    "Head Position Requirement": "Head must be centered and face the camera directly",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression with both eyes open",
    "Head Covering Allowed (Yes/No)": "Yes, for religious purposes only",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Less than or equal to 240 KB",
    "Additional Notes": "Minimum acceptable dimensions are 600 x 600 pixels; maximum acceptable dimensions are 1200 x 1200 pixels",
    "Last Updated": "2025-03-16"
}])
China = pd.DataFrame ([{
    "Country": "China",
    "ISO Code": "CN",
    "Passport Photo Size (Width x Height, mm)": "33 x 48",
    "Passport Photo Size (Width x Height, inch)": None,
    "Visa Photo Size (Width x Height, mm)": "33 x 48",
    "Visa Photo Size (Width x Height, inch)": None,
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
    "Aspect Ratio (Passport)": None,
    "Aspect Ratio (Visa)": 0.69,
    "Background Color": "White or close to white",
    "Head Position Requirement": "Head centered, facing camera, entire head and face clearly visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Printed on glossy finish photo paper",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photo must be taken within the last 6 months; width of head: 15mm to 22mm; head height: 28mm to 33mm",
    "Last Updated": "2024-03-05"
}])
Australia = pd.DataFrame([{
    "Country": "Australia",
    "ISO Code": "AU",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38-1.57 x 1.77-1.97",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inch)": "1.38-1.57 x 1.77-1.97",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "Plain white or light grey",
    "Head Position Requirement": "Head centered, facing camera, entire head and shoulders visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Printed on high-quality paper",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos should be no older than six months; head size between 32mm and 36mm from chin to crown",
    "Last Updated": "2025-03-17"
}])
India = pd.DataFrame([{
    "Country": "India",
    "ISO Code": "IN",
    "Passport Photo Size (Width x Height, mm)": "51 x 51",
    "Passport Photo Size (Width x Height, inch)": "2 x 2",
    "Visa Photo Size (Width x Height, mm)": "51 x 51",
    "Visa Photo Size (Width x Height, inch)": "2 x 2",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 1,
    "Aspect Ratio (Visa)": 1,
    "Background Color": "Plain white",
    "Head Position Requirement": "Head centered, facing camera, entire head and face clearly visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "10 KB - 300 KB",
    "Additional Notes": "Photos should be no older than six months; head size between 25mm and 35mm from chin to crown",
    "Last Updated": "2025-03-17"
}])
Argentina = pd.DataFrame([{
    "Country": "Argentina",
    "ISO Code": "AR",
    "Passport Photo Size (Width x Height, mm)": "40 x 40",
    "Passport Photo Size (Width x Height, inch)": "1.57 x 1.57",
    "Visa Photo Size (Width x Height, mm)": "40 x 40",
    "Visa Photo Size (Width x Height, inch)": "1.57 x 1.57",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 1,
    "Aspect Ratio (Visa)": 1,
    "Background Color": "White or light-colored",
    "Head Position Requirement": "Head centered, facing camera",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious purposes",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Not specified",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photo should be taken within the last 6 months; head size should occupy about 70-80% of the photo",
    "Last Updated": "2025-03-17"
}])
Kazakhstan = pd.DataFrame([{
    "Country": "Kazakhstan",
    "ISO Code": "KZ",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White or light-colored",
    "Head Position Requirement": "Head centered, facing camera, entire face visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Not specified",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photo must be taken within the last 6 months; head size should be between 70-80% of the photo height",
    "Last Updated": "2025-03-17"
}])
Algeria = pd.DataFrame([{
    "Country": "Algeria",
    "ISO Code": "DZ",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "Plain white or light-colored",
    "Head Position Requirement": "Head centered, facing camera, eyes open and clearly visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Printed on photo-quality paper without borders",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos must be recent and identical; no shadows on face or background; no digital alterations",
    "Last Updated": "2025-03-17"
}])
Congo = pd.DataFrame([{
    "Country": "Republic of the Congo (Congo-Brazzaville)",
    "ISO Code": "CG",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "40 x 40",
    "Visa Photo Size (Width x Height, inch)": "1.57 x 1.57",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 1.00,
    "Background Color": "White",
    "Head Position Requirement": "Head centered, facing camera, entire face visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Printed on high-quality photo paper",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background",
    "Last Updated": "2025-03-17"
}])
Greenland = pd.DataFrame([{
    "Country": "Greenland",
    "ISO Code": "GL",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "Plain white or light-colored",
    "Head Position Requirement": "Head centered, facing camera, entire face visible",
    "Glasses Allowed (Yes/No)": "Yes",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Printed on high-quality photo paper",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
    "Last Updated": "2025-03-17"
}])
ArabSaudi = pd.DataFrame([{
    "Country": "Saudi Arabia",
    "ISO Code": "SA",
    "Passport Photo Size (Width x Height, mm)": "40 x 60",
    "Passport Photo Size (Width x Height, inch)": "1.57 x 2.36",
    "Visa Photo Size (Width x Height, mm)": "50 x 50",
    "Visa Photo Size (Width x Height, inch)": "1.97 x 1.97",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
    "Aspect Ratio (Passport)": 0.67,
    "Aspect Ratio (Visa)": 1.00,
    "Background Color": "Plain white",
    "Head Position Requirement": "Head centered, facing camera, entire face visible",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": 600,
    "File Format (JPEG/PNG)": "Color",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
    "Last Updated": "2025-03-17"
}])
Mexico = pd.DataFrame([{
    "Country": "Mexico",
    "ISO Code": "MX",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered, facing camera, entire face visible",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed",
    "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
    "Resolution (dpi)": "Not specified",
    "File Format (JPEG/PNG)": "Color",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
    "Last Updated": "2025-03-17"
}])
Indonesia = pd.DataFrame([
    {
        "Country": "Indonesia",
        "ISO Code": "ID",
        "Passport Photo Size (Width x Height, mm)": "51 x 51",
        "Passport Photo Size (Width x Height, inch)": "2 x 2",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Head centered, facing camera, entire face visible",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed",
        "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (taken within the last 6 months); head size between 1 and 1 3/8 inches from chin to crown; no shadows on face or background; no digital alterations",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Iran",
        "ISO Code": "IR",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "400 x 600 pixels",
        "Visa Photo Size (Width x Height, inch)": "Not applicable",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Head centered, facing camera, entire face visible",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed",
        "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Equal to or less than 500 kB",
        "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
        "Last Updated": "2025-03-17"
    },
    { 
        "Country": "Mexico",
        "ISO Code": "MX",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered, facing camera, entire face visible",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed",
        "Head Covering Allowed (Yes/No)": "Yes, for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
        "Last Updated": "2025-03-17"
        },
        {
        "Country": "Libya",
        "ISO Code": "LY",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, facing camera",
        "Glasses Allowed (Yes/No)": "Yes, under certain circumstances",
        "Expression Rules": "Neutral expression, no smile",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "High-resolution",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent (within the last 6 months); no shadows; face must be clearly visible; no edits or digital alterations",
        "Last Updated": "2025-03-17"
        },
        { 
        "Country": "Mongolia",
        "ISO Code": "MN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "30 x 40",
        "Visa Photo Size (Width x Height, inch)": "1.18 x 1.57",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.75,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, facing camera",
        "Glasses Allowed (Yes/No)": "Yes, under certain circumstances",
        "Expression Rules": "Neutral expression, no smile",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "High-resolution",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent (within the last 6 months); no shadows; face must be clearly visible; no edits or digital alterations",
        "Last Updated": "2025-03-17"
        },
         {
        "Country": "Peru",
        "ISO Code": "PE",
        "Passport Photo Size (Width x Height, mm)": "51 x 51",
        "Passport Photo Size (Width x Height, inch)": "2 x 2",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, facing camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, no smile",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "High-resolution",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (within the last 6 months); no shadows; face must be clearly visible; no edits or digital alterations",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Chad",
        "ISO Code": "TD",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inch)": "2 x 2",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inch)": "2 x 2",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head centered, facing camera",
        "Glasses Allowed (Yes/No)": "Yes, under certain circumstances",
        "Expression Rules": "Neutral expression, mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "High-resolution",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (taken within the last 6 months); no shadows on face or background; no digital alterations",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Vietnam",
        "ISO Code": "VN",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inch)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Face should occupy 70-80% of the photo; distance from top of head to chin should be 32-36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Schengen Area",
        "ISO Code": "SCH",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light-colored",
        "Head Position Requirement": "Face should occupy 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Japan",
        "ISO Code": "JP",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain, light-colored",
        "Head Position Requirement": "Face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "France",
        "ISO Code": "FR",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light gray",
        "Head Position Requirement": "Face should occupy 70-80% of the photo; head height should be 30-36mm",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Laos",
        "ISO Code": "LA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face should be centered, looking straight at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not create glare",
        "Expression Rules": "Neutral expression, mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent (taken within the last six months)",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "United States",
        "ISO Code": "US",
        "Passport Photo Size (Width x Height, mm)": "51 x 51",
        "Passport Photo Size (Width x Height, inch)": "2 x 2",
        "Visa Photo Size (Width x Height, mm)": "51 x 51",
        "Visa Photo Size (Width x Height, inch)": "2 x 2",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White or off-white",
        "Head Position Requirement": "Head height between 1 and 1 3/8 inches; eye height between 1 1/8 and 1 3/8 inches from bottom of photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "United Kingdom",
        "ISO Code": "GB",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain cream or light grey",
        "Head Position Requirement": "Head must be between 29mm and 34mm from chin to crown",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last month",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Canada",
        "ISO Code": "CA",
        "Passport Photo Size (Width x Height, mm)": "50 x 70",
        "Passport Photo Size (Width x Height, inch)": "1.97 x 2.76",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 0.71,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain white or light-colored",
        "Head Position Requirement": "Head height between 31mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be signed by the photographer or a guarantor",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Australia",
        "ISO Code": "AU",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain white or light grey",
        "Head Position Requirement": "Head height between 32mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Brazil",
        "ISO Code": "BR",
        "Passport Photo Size (Width x Height, mm)": "50 x 70",
        "Passport Photo Size (Width x Height, inch)": "1.97 x 2.76",
        "Visa Photo Size (Width x Height, mm)": "50 x 70",
        "Visa Photo Size (Width x Height, inch)": "1.97 x 2.76",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.71,
        "Aspect Ratio (Visa)": 0.71,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (within the last six months); no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "South Korea",
        "ISO Code": "KR",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Less than 240 KB",
        "Additional Notes": "Photos must be recent (within the last six months); head must be between 25-35mm",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "South Africa",
        "ISO Code": "ZA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photos must be recent (within the last six months); no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "United Kingdom",
        "ISO Code": "GB",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain cream or light grey",
        "Head Position Requirement": "Head must be between 29mm and 34mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last month; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "New Zealand",
        "ISO Code": "NZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain light-colored",
        "Head Position Requirement": "Head must be between 29mm and 34mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Nigeria",
        "ISO Code": "NG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain white",
        "Head Position Requirement": "Head must be between 32mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Singapore",
        "ISO Code": "SG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inch)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain white",
        "Head Position Requirement": "Head must be between 32mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, as long as eyes are clearly visible and there is no glare",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last three months; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Germany",
        "ISO Code": "DE",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light grey",
        "Head Position Requirement": "Head height should be between 32mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Italy",
        "ISO Code": "IT",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light grey or neutral",
        "Head Position Requirement": "Head height should be between 32mm and 36mm; face centered and looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression with mouth closed",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "Color",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on the face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Pakistan",
        "ISO Code": "PK",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
    "Country": "Cambodia",
    "ISO Code": "KH",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
    },
    {
    "Country": "United Arab Emirates",
    "ISO Code": "AE",
    "Passport Photo Size (Width x Height, mm)": "43 x 55",
    "Passport Photo Size (Width x Height, inches)": "1.69 x 2.17",
    "Visa Photo Size (Width x Height, mm)": "43 x 55",
    "Visa Photo Size (Width x Height, inches)": "1.69 x 2.17",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Not specified",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
},{
        "Country": "Madagascar",
        "ISO Code": "MG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Malawi",
        "ISO Code": "MW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Malaysia",
        "ISO Code": "MY",
        "Passport Photo Size (Width x Height, mm)": "35 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "35 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.70,
        "Aspect Ratio (Visa)": 0.70,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Maldives",
        "ISO Code": "MV",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Mali",
        "ISO Code": "ML",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
    "Country": "Malta",
    "ISO Code": "MT",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
},{
    "Country": "Mauritania",
    "ISO Code": "MR",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
{
    "Country": "Mexico",
    "ISO Code": "MX",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
}
,{
    "Country": "Mexico",
    "ISO Code": "MX",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
{
    "Country": "Micronesia",
    "ISO Code": "FM",
    "Passport Photo Size (Width x Height, mm)": "51 x 51",
    "Passport Photo Size (Width x Height, inches)": "2 x 2",
    "Visa Photo Size (Width x Height, mm)": "51 x 51",
    "Visa Photo Size (Width x Height, inches)": "2 x 2",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 1.0,
    "Aspect Ratio (Visa)": 1.0,
    "Background Color": "White",
    "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "300",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
    "Additional Notes": "Photo must be in color; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
 {
        "Country": "Moldova",
        "ISO Code": "MD",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Monaco",
        "ISO Code": "MC",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Montenegro",
        "ISO Code": "ME",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Morocco",
        "ISO Code": "MA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Mozambique",
        "ISO Code": "MZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Namibia",
        "ISO Code": "NA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Nauru",
        "ISO Code": "NR",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Nepal",
        "ISO Code": "NP",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head centered; face covering 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "Photo must be in color; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Netherlands",
        "ISO Code": "NL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light gray",
        "Head Position Requirement": "Head straight, face centered; head height 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for medical or religious reasons",
        "Resolution (dpi)": "400",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 10 MB",
        "Additional Notes": "No shadows on face or background; ears should be visible",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "New Zealand",
        "ISO Code": "NZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain, light-colored (preferably light grey or blue)",
        "Head Position Requirement": "Head straight, face centered; head height between 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for medical or religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 500 KB; Maximum 10 MB",
        "Additional Notes": "No shadows on face or background; photo must be taken within the last six months",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Nicaragua",
        "ISO Code": "NI",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered; head height between 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for medical or religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "No shadows on face or background; photo must be in color",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Norway",
        "ISO Code": "NO",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Oman",
        "ISO Code": "OM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered; head height between 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for medical or religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "No shadows on face or background; photo must be in color",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Palau",
        "ISO Code": "PW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered; head height between 70-80% of the photo",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for medical or religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Minimum 10 KB; Maximum 1 MB",
        "Additional Notes": "No shadows on face or background; photo must be in color",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Panama",
        "ISO Code": "PA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Papua New Guinea",
        "ISO Code": "PG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Paraguay",
        "ISO Code": "PY",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Philippines",
        "ISO Code": "PH",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Poland",
        "ISO Code": "PL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Portugal",
        "ISO Code": "PT",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Qatar",
        "ISO Code": "QA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Romania",
        "ISO Code": "RO",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Rwanda",
        "ISO Code": "RW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Saint Kitts and Nevis",
        "ISO Code": "KN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Saint Vincent and the Grenadines",
        "ISO Code": "VC",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Samoa",
        "ISO Code": "WS",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "San Marino",
        "ISO Code": "SM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "São Tomé and Príncipe",
        "ISO Code": "ST",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Senegal",
        "ISO Code": "SN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Serbia",
        "ISO Code": "RS",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Seychelles",
        "ISO Code": "SC",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Sierra Leone",
        "ISO Code": "SL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Solomon Islands",
        "ISO Code": "SB",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Somalia",
        "ISO Code": "SO",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "South Africa",
        "ISO Code": "ZA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "South Sudan",
        "ISO Code": "SS",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Spain",
        "ISO Code": "ES",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Sri Lanka",
        "ISO Code": "LK",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Sudan",
        "ISO Code": "SD",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Suriname",
        "ISO Code": "SR",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Eswatini (formerly Swaziland)",
        "ISO Code": "SZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Sweden",
        "ISO Code": "SE",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Switzerland",
        "ISO Code": "CH",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Syria",
        "ISO Code": "SY",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Taiwan",
        "ISO Code": "TW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Tajikistan",
        "ISO Code": "TJ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Thailand",
        "ISO Code": "TH",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Central African Republic",
        "ISO Code": "CF",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },{
        "Country": "Marshall Islands",
        "ISO Code": "MH",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Togo",
        "ISO Code": "TG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Trinidad and Tobago",
        "ISO Code": "TT",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Turkmenistan",
        "ISO Code": "TM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Tuvalu",
        "ISO Code": "TV",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Uganda",
        "ISO Code": "UG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Ukraine",
        "ISO Code": "UA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Uruguay",
        "ISO Code": "UY",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Uzbekistan",
        "ISO Code": "UZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Vanuatu",
        "ISO Code": "VU",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Vatican City",
        "ISO Code": "VA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Andorra",
        "ISO Code": "AD",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Antigua and Barbuda",
        "ISO Code": "AG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Armenia",
        "ISO Code": "AM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Afghanistan",
        "ISO Code": "AF",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Albania",
        "ISO Code": "AL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Azerbaijan",
        "ISO Code": "AZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height 32mm-36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 350 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
    "Country": "Bahrain",
    "ISO Code": "BH",
    "Passport Photo Size (Width x Height, mm)": "40 x 60",
    "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
    "Visa Photo Size (Width x Height, mm)": "40 x 60",
    "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.67,
    "Aspect Ratio (Visa)": 0.67,
    "Background Color": "White",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
    "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Maximum 350 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
},{
    "Country": "Bahamas",
    "ISO Code": "BS",
    "Passport Photo Size (Width x Height, mm)": "50 x 70",
    "Passport Photo Size (Width x Height, inches)": "1.97 x 2.76",
    "Visa Photo Size (Width x Height, mm)": "50 x 70",
    "Visa Photo Size (Width x Height, inches)": "1.97 x 2.76",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.71,
    "Aspect Ratio (Visa)": 0.71,
    "Background Color": "White",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
    "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Maximum 350 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
{
    "Country": "Bangladesh",
    "ISO Code": "BD",
    "Passport Photo Size (Width x Height, mm)": "45 x 55",
    "Passport Photo Size (Width x Height, inches)": "1.77 x 2.17",
    "Visa Photo Size (Width x Height, mm)": "45 x 55",
    "Visa Photo Size (Width x Height, inches)": "1.77 x 2.17",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.82,
    "Aspect Ratio (Visa)": 0.82,
    "Background Color": "White",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Maximum 500 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
{
    "Country": "Barbados",
    "ISO Code": "BB",
    "Passport Photo Size (Width x Height, mm)": "50 x 50",
    "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
    "Visa Photo Size (Width x Height, mm)": "50 x 50",
    "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 1.00,
    "Aspect Ratio (Visa)": 1.00,
    "Background Color": "White",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
    "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Maximum 300 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
}
,{
    "Country": "Belarus",
    "ISO Code": "BY",
    "Passport Photo Size (Width x Height, mm)": "40 x 50",
    "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
    "Visa Photo Size (Width x Height, mm)": "40 x 50",
    "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.80,
    "Aspect Ratio (Visa)": 0.80,
    "Background Color": "White",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
    "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG",
    "File Size Limit (KB/MB)": "Maximum 500 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
}
,{
    "Country": "Belgium",
    "ISO Code": "BE",
    "Passport Photo Size (Width x Height, mm)": "35 x 45",
    "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Visa Photo Size (Width x Height, mm)": "35 x 45",
    "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
    "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
    "Aspect Ratio (Passport)": 0.78,
    "Aspect Ratio (Visa)": 0.78,
    "Background Color": "Light Gray",
    "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 29mm and 34mm",
    "Glasses Allowed (Yes/No)": "No",
    "Expression Rules": "Neutral expression, mouth closed, both eyes open",
    "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
    "Resolution (dpi)": "600",
    "File Format (JPEG/PNG)": "JPEG or PNG",
    "File Size Limit (KB/MB)": "Maximum 350 KB",
    "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    "Last Updated": "2025-03-17"
},
 {
        "Country": "Belize",
        "ISO Code": "BZ",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Benin",
        "ISO Code": "BJ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Bhutan",
        "ISO Code": "BT",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 400 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Bosnia and Herzegovina",
        "ISO Code": "BA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Botswana",
        "ISO Code": "BW",
        "Passport Photo Size (Width x Height, mm)": "30 x 40",
        "Passport Photo Size (Width x Height, inches)": "1.18 x 1.57",
        "Visa Photo Size (Width x Height, mm)": "30 x 40",
        "Visa Photo Size (Width x Height, inches)": "1.18 x 1.57",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.75,
        "Aspect Ratio (Visa)": 0.75,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 25mm and 30mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Brunei",
        "ISO Code": "BN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Bulgaria",
        "ISO Code": "BG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light Grey",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "Yes, if no glare and eyes are clearly visible",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 400 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Burkina Faso",
        "ISO Code": "BF",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },{
        "Country": "Burundi",
        "ISO Code": "BI",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 35mm and 40mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken withinthe last six months; no shadows on face or background",
"Last Updated": "2025-03-17"
},
 {
        "Country": "Cameroon",
        "ISO Code": "CM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Cape Verde",
        "ISO Code": "CV",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Chile",
        "ISO Code": "CL",
        "Passport Photo Size (Width x Height, mm)": "45 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.77 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "45 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.77 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 30mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Colombia",
        "ISO Code": "CO",
        "Passport Photo Size (Width x Height, mm)": "40 x 40",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.57",
        "Visa Photo Size (Width x Height, mm)": "40 x 40",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.57",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 28mm and 32mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Comoros",
        "ISO Code": "KM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Congo",
        "ISO Code": "CG",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Costa Rica",
        "ISO Code": "CR",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 30mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Croatia",
        "ISO Code": "HR",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light Gray",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Cuba",
        "ISO Code": "CU",
        "Passport Photo Size (Width x Height, mm)": "40 x 40",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.57",
        "Visa Photo Size (Width x Height, mm)": "40 x 40",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.57",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 28mm and 32mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Cyprus",
        "ISO Code": "CY",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Czech Republic",
        "ISO Code": "CZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Denmark",
        "ISO Code": "DK",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light Gray",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    }, {
        "Country": "Djibouti",
        "ISO Code": "DJ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Dominica",
        "ISO Code": "DM",
        "Passport Photo Size (Width x Height, mm)": "45 x 35",
        "Passport Photo Size (Width x Height, inches)": "1.77 x 1.38",
        "Visa Photo Size (Width x Height, mm)": "45 x 35",
        "Visa Photo Size (Width x Height, inches)": "1.77 x 1.38",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.29,
        "Aspect Ratio (Visa)": 1.29,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Dominican Republic",
        "ISO Code": "DO",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "East Timor",
        "ISO Code": "TL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Ecuador",
        "ISO Code": "EC",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Egypt",
        "ISO Code": "EG",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "El Salvador",
        "ISO Code": "SV",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Equatorial Guinea",
        "ISO Code": "GQ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
     {
        "Country": "Eritrea",
        "ISO Code": "ER",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Ethiopia",
        "ISO Code": "ET",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Fiji",
        "ISO Code": "FJ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Maximum 500 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Finland",
        "ISO Code": "FI",
        "Passport Photo Size (Width x Height, mm)": "36 x 47",
        "Passport Photo Size (Width x Height, inches)": "1.42 x 1.85",
        "Visa Photo Size (Width x Height, mm)": "36 x 47",
        "Visa Photo Size (Width x Height, inches)": "1.42 x 1.85",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.77,
        "Aspect Ratio (Visa)": 0.77,
        "Background Color": "Light gray",
        "Head Position Requirement": "Face centered, looking directly at the camera; head height should be between 32mm and 36mm",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Maximum 250 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Gabon",
        "ISO Code": "GA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; ears should be visible; no shadows on face or background",
        "Last Updated": "2024-05-14"
    },
    {
        "Country": "Germany",
        "ISO Code": "DE",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light gray",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2024-05-14"
    },
    {
        "Country": "Greece",
        "ISO Code": "GR",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "Light gray or white",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2024-05-14"
    },{
        "Country": "Grenada",
        "ISO Code": "GD",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Guatemala",
        "ISO Code": "GT",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Guinea-Bissau",
        "ISO Code": "GW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Guyana",
        "ISO Code": "GY",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Haiti",
        "ISO Code": "HT",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Honduras",
        "ISO Code": "HN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Hong Kong",
        "ISO Code": "HK",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Hungary",
        "ISO Code": "HU",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2024-05-14"
    }, 
     {
        "Country": "Iceland",
        "ISO Code": "IS",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "India",
        "ISO Code": "IN",
        "Passport Photo Size (Width x Height, mm)": "51 x 51",
        "Passport Photo Size (Width x Height, inches)": "2 x 2",
        "Visa Photo Size (Width x Height, mm)": "51 x 51",
        "Visa Photo Size (Width x Height, inches)": "2 x 2",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "10 KB - 300 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background; ears should be visible",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Iraq",
        "ISO Code": "IQ",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
        "Last Updated": "2025-03-17"
    },
    {
        "Country": "Ireland",
        "ISO Code": "IE",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Plain white or light grey",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious or medical reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "715 KB",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background; facial features must be clearly visible",
        "Last Updated": "2025-03-17"
    }, {
        "Country": "Israel",
        "ISO Code": "IL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Ivory Coast",
        "ISO Code": "CI",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Jamaica",
        "ISO Code": "JM",
        "Passport Photo Size (Width x Height, mm)": "45 x 35",
        "Passport Photo Size (Width x Height, inches)": "1.77 x 1.38",
        "Visa Photo Size (Width x Height, mm)": "45 x 35",
        "Visa Photo Size (Width x Height, inches)": "1.77 x 1.38",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.29,
        "Aspect Ratio (Visa)": 1.29,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    },
    {
        "Country": "Jordan",
        "ISO Code": "JO",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    },
     {
        "Country": "Kazakhstan",
        "ISO Code": "KZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent; no shadows on face or background"
    },
    {
        "Country": "Kenya",
        "ISO Code": "KE",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Kosovo",
        "ISO Code": "XK",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent; no shadows on face or background"
    },
    {
        "Country": "Kuwait",
        "ISO Code": "KW",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
 {
        "Country": "Kyrgyzstan",
        "ISO Code": "KG",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Laos",
        "ISO Code": "LA",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Latvia",
        "ISO Code": "LV",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light gray",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    },
    {
        "Country": "Lebanon",
        "ISO Code": "LB",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    },
     {
        "Country": "Lesotho",
        "ISO Code": "LS",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Liberia",
        "ISO Code": "LR",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Libya",
        "ISO Code": "LY",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Liechtenstein",
        "ISO Code": "LI",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "Light gray",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be recent; no shadows on face or background"
    },
    {
        "Country": "Lithuania",
        "ISO Code": "LT",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "Yes",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "600",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    }, {
        "Country": "Luxembourg",
        "ISO Code": "LU",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "North Macedonia",
        "ISO Code": "MK",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "Not specified",
        "File Format (JPEG/PNG)": "Not specified",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
     {
        "Country": "Zimbabwe",
        "ISO Code": "ZW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "Yes, if they do not obscure the eyes or cause reflections",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Palestine",
        "ISO Code": "PS",
        "Passport Photo Size (Width x Height, mm)": "40 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "40 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 1.97",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.80,
        "Aspect Ratio (Visa)": 0.80,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Bolivia",
        "ISO Code": "BO",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Democratic Republic of the Congo",
        "ISO Code": "CD",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "East Timor",
        "ISO Code": "TL",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Eritrea",
        "ISO Code": "ER",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White or light-colored",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Gambia",
        "ISO Code": "GM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Guinea",
        "ISO Code": "GN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background",
    },
     {
        "Country": "Kiribati",
        "ISO Code": "KI",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos? (Yes/No)": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Head straight, face centered, looking directly at the camera",
        "Glasses Allowed (Yes/No)": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed (Yes/No)": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format (JPEG/PNG)": "JPEG or PNG",
        "File Size Limit (KB/MB)": "Not specified",
        "Additional Notes": "Avoid white clothing to contrast with the background; photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Saint Lucia",
        "ISO Code": "LC",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "South Sudan",
        "ISO Code": "SS",
        "Passport Photo Size (Width x Height, mm)": "50 x 50",
        "Passport Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Visa Photo Size (Width x Height, mm)": "50 x 50",
        "Visa Photo Size (Width x Height, inches)": "1.97 x 1.97",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Tanzania",
        "ISO Code": "TZ",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Tunisia",
        "ISO Code": "TN",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Venezuela",
        "ISO Code": "VE",
        "Passport Photo Size (Width x Height, mm)": "32 x 32",
        "Passport Photo Size (Width x Height, inches)": "1.26 x 1.26",
        "Visa Photo Size (Width x Height, mm)": "32 x 32",
        "Visa Photo Size (Width x Height, inches)": "1.26 x 1.26",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 1.00,
        "Aspect Ratio (Visa)": 1.00,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Yemen",
        "ISO Code": "YE",
        "Passport Photo Size (Width x Height, mm)": "40 x 60",
        "Passport Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Visa Photo Size (Width x Height, mm)": "40 x 60",
        "Visa Photo Size (Width x Height, inches)": "1.57 x 2.36",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.67,
        "Aspect Ratio (Visa)": 0.67,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Zambia",
        "ISO Code": "ZM",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    },
    {
        "Country": "Zimbabwe",
        "ISO Code": "ZW",
        "Passport Photo Size (Width x Height, mm)": "35 x 45",
        "Passport Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Visa Photo Size (Width x Height, mm)": "35 x 45",
        "Visa Photo Size (Width x Height, inches)": "1.38 x 1.77",
        "Size Difference Between Visa & Passport Photos?": "No",
        "Aspect Ratio (Passport)": 0.78,
        "Aspect Ratio (Visa)": 0.78,
        "Background Color": "White",
        "Head Position Requirement": "Full face, centered, looking directly at the camera",
        "Glasses Allowed": "No",
        "Expression Rules": "Neutral expression, mouth closed, both eyes open",
        "Head Covering Allowed": "No, unless for religious reasons",
        "Resolution (dpi)": "300",
        "File Format": "JPEG or PNG",
        "File Size Limit": "Not specified",
        "Additional Notes": "Photo must be taken within the last six months; no shadows on face or background"
    }
    
])

# Nối dữ liệu mới vào DataFrame hiện có
df = pd.concat([df, Indonesia], ignore_index=True)
df = pd.concat([df, Mexico], ignore_index=True)
df = pd.concat([df, ArabSaudi], ignore_index=True)
df = pd.concat([df, Greenland], ignore_index=True)
df = pd.concat([df, Congo], ignore_index=True)
df = pd.concat([df, Algeria], ignore_index=True)
df = pd.concat([df, Kazakhstan], ignore_index=True)
df = pd.concat([df, Argentina], ignore_index=True)
df = pd.concat([df, UnitedStates], ignore_index=True)
df = pd.concat([df, China], ignore_index=True)
df = pd.concat([df, Australia], ignore_index=True)
df = pd.concat([df, India], ignore_index=True)

def filter_file_format(format_value):
    if isinstance(format_value, str):  # Kiểm tra nếu format_value là chuỗi
        allowed_formats = {"JPEG", "PNG"}
        formats = set(map(str.strip, format_value.split("or")))
        if formats.issubset(allowed_formats):
            return format_value
    return "Not Specified"  # Nếu không phải chuỗi hoặc không hợp lệ, đặt lại "Not Specified"

df["File Format (JPEG/PNG)"] = df["File Format (JPEG/PNG)"].apply(filter_file_format)

def convert_mm_to_inch(size_mm):
    try:
        width_mm, height_mm = map(float, size_mm.split(" x "))  # Tách giá trị
        width_inch = round(width_mm / 25.4, 2)  # Chuyển sang inch, làm tròn 2 chữ số
        height_inch = round(height_mm / 25.4, 2)
        return f"{width_inch} x {height_inch}"  # Trả về định dạng mới
    except:
        return None  # Xử lý lỗi nếu có
def convert_mm_to_inch(size_mm):
    try:
        width_mm, height_mm = map(float, size_mm.split(" x "))  # Tách giá trị
        width_inch = round(width_mm / 25.4, 2)  # Chuyển sang inch, làm tròn 2 chữ số
        height_inch = round(height_mm / 25.4, 2)
        return f"{width_inch} x {height_inch}"  # Trả về định dạng mới
    except:
        return None  # Xử lý lỗi nếu có
def check_size_difference(passport_size, visa_size):
    try:
        # Tách kích thước theo định dạng "Width x Height"
        passport_width, passport_height = map(float, passport_size.split(" x "))
        visa_width, visa_height = map(float, visa_size.split(" x "))
        
        # So sánh kích thước Passport và Visa
        if passport_width == visa_width and passport_height == visa_height:
            return "No"  # Không có sự khác biệt
        else:
            return "Yes"  # Có sự khác biệt
    except:
        return "Invalid"  # Tránh lỗi nếu dữ liệu không đúng
def convert_size_and_aspect_ratio(size_mm):
    try:
        width_mm, height_mm = map(float, size_mm.split(" x "))  # Tách giá trị width & height
        width_inch = round(width_mm / 25.4, 2)  # Chuyển sang inch, làm tròn 2 số thập phân
        height_inch = round(height_mm / 25.4, 2)
        aspect_ratio = round(width_inch / height_inch, 2)  # Tính Aspect Ratio
        return f"{width_inch} x {height_inch}", aspect_ratio  # Trả về cả inch size và Aspect Ratio
    except:
        return None, None  # Xử lý lỗi nếu dữ liệu sai định dạng
# Chuyen PP size mm to inch
df["Passport Photo Size (Width x Height, inch)"] = df["Passport Photo Size (Width x Height, mm)"].apply(convert_mm_to_inch)
# Chuyen VS size mm to inch
df["Visa Photo Size (Width x Height, inch)"] = df["Visa Photo Size (Width x Height, mm)"].apply(convert_mm_to_inch)
# Áp dụng hàm cho Passport Photo Size
df[["Passport Photo Size (Width x Height, inch)", "Aspect Ratio (Passport)"]] = df["Passport Photo Size (Width x Height, mm)"].apply(
    lambda x: pd.Series(convert_size_and_aspect_ratio(x))
)
# Áp dụng hàm cho Visa Photo Size
df[["Visa Photo Size (Width x Height, inch)", "Aspect Ratio (Visa)"]] = df["Visa Photo Size (Width x Height, mm)"].apply(
    lambda x: pd.Series(convert_size_and_aspect_ratio(x))
)
# Check xem Size nó khác nhau hay không
df["Size Difference Between Visa & Passport Photos? (Yes/No)"] = df.apply(
    lambda row: check_size_difference(row["Passport Photo Size (Width x Height, mm)"], 
                                      row["Visa Photo Size (Width x Height, mm)"]), 
    axis=1
)
# # Lưu lại file CSV mới
# df = df.drop_duplicates(subset=["Country"], keep="first")
# # Save the updated DataFrame to a CSV file
# df.to_csv("file_updated.csv", index=False)

# # Display the DataFrame
# df = df.drop(columns=['Passport Photo Size (Width x Height, inches)', 
#                       'Visa Photo Size (Width x Height, inches)'])
# # df.to_csv("file_updated.csv", index=False)
# if "Last Updated" in df.columns:
#     # Đếm số lần lặp lại của từng giá trị
#     value_counts = df[""].value_counts()

#     # Hiển thị danh sách các giá trị và số lần xuất hiện
#     print("Danh sách các giá trị của 'Last Updated' và số lần xuất hiện:")
#     print(value_counts)
# else:
#     print("Cột 'Last Updated' không tồn tại trong file CSV.")
df
# Out:
#                                        Country ISO Code  \
# 0                                       Russia       RU
# 1                Canada - Adult (16 and older)       CA
# 2                 Canada - Children (under 16)       CA
# 3                                    Indonesia       ID
# 4                                         Iran       IR
# ..                                         ...      ...
# 198                                  Greenland       GL
# 199  Republic of the Congo (Congo-Brazzaville)       CG
# 200                                    Algeria       DZ
# 202                                  Argentina       AR
# 204                                      China       CN
#
#     Passport Photo Size (Width x Height, mm)  \
# 0                                    35 x 45
# 1                                    50 x 70
# 2                                    50 x 70
# 3                                    51 x 51
# 4                                    40 x 60
# ...
