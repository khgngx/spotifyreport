# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\ADMIN\Downloads\passport_photo_requirements (1).csv')
df.loc[0, 'Last Updated'] = '16/03/2025'

df
# Out:
#                          Country ISO Code  \
# 0                         Russia       RU
# 1  Canada - Adult (16 and older)       CA
# 2   Canada - Children (under 16)       CA
#
#   Passport Photo Size (Width x Height, mm)  \
# 0                                  35 x 45
# 1                                  50 x 70
# 2                                  50 x 70
#
#   Passport Photo Size (Width x Height, inch)  \
# 0                                1.38 x 1.77
# 1                                   2 x 2.75
# 2                                   2 x 2.75
#
#   Visa Photo Size (Width x Height, mm) Visa Photo Size (Width x Height, inch)  \
# 0                              35 x 45                            1.38 x 1.77
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
#
#   Size Difference Between Visa & Passport Photos? (Yes/No)  \
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
#
#    Aspect Ratio (Passport)  Aspect Ratio (Visa)              Background Color  \
# 0                     0.78                 0.78                   Plain white
# 1                     0.71                  NaN  Plain white or light-colored
# 2                     0.71                  NaN  Plain white or light-colored
#
#                            Head Position Requirement  \
# 0                      Head centered, facing forward
# 1  Head and shoulders squared to camera, head not...
# 2  Head and shoulders only, parent's hands must n...
#
#        Glasses Allowed (Yes/No)                       Expression Rules  \
# 0                           Yes       Neutral expression, mouth closed
# 1  Yes, but no glare/reflection       Neutral expression, mouth closed
# 2  Yes, but no glare/reflection  Minor variations allowed for newborns
#
#           Head Covering Allowed (Yes/No) Resolution (dpi)  \
# 0            Yes, for religious purposes    Not specified
# 1  Yes, for religious or medical reasons    Not specified
# 2  Yes, for religious or medical reasons    Not specified
#
#    File Format (JPEG/PNG) File Size Limit (KB/MB)  \
# 0           Not specified           Not specified
# 1  Black & white or color           Not specified
# 2  Black & white or color           Not specified
#
#                                     Additional Notes Last Updated
# 0  Photo should be taken within 6 months before a...   16/03/2025
# 1  Photos must be taken by a commercial photographer   2015-05-09
# 2  Photos must be taken by a commercial photographer   2015-05-09
